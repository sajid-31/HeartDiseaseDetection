# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sex = pd.get_dummies(df['Sex'],drop_first=True)
ST_Slope = pd.get_dummies(df['ST_Slope'],drop_first=True)
ExerciseAngina = pd.get_dummies(df['ExerciseAngina'],drop_first=True)
RestingECG = pd.get_dummies(df['RestingECG'],drop_first=True)
ChestPainType = pd.get_dummies(df['ChestPainType'],drop_first=True)

# %%
dataset = pd.concat([df,sex,ST_Slope,ExerciseAngina,RestingECG,ChestPainType],axis=1)

# %%
dataset = dataset.drop(["Sex","ChestPainType","RestingECG","ExerciseAngina","ST_Slope"],axis=1)

# %%
dataset
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#          M   Flat     Up      Y  Normal     ST    ATA    NAP     TA
# 0     True  False   True  False    True  False   True  False  False
# 1    False   True  False  False    True  False  False   True  False
# 2     True  False   True  False   False   True   True  False  False
# 3    False   True  False   True    True  False  False  False  False
# 4     True  False   True  False    True  False  False   True  False
# ..     ...    ...    ...    ...     ...    ...    ...    ...    ...
# 913   True   True  False  False    True  False  False  False   True
# 914   True   True  False  False    True  False  False  False  False
# 915   True   True  False   True    True  False  False  False  False
# 916  False   True  False  False   False  False   True  False  False
# 917   True  False   True  False    True  False  False   True  False
#
# [918 rows x 16 columns]

# %%
dataset.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease', 'M', 'Flat', 'Up', 'Y', 'Normal', 'ST', 'ATA', 'NAP',
#        'TA'],
#       dtype='object')

# %%
X = dataset.drop('HeartDisease',axis=1)
Y = dataset['HeartDisease']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', None)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.75354017,  0.40398537, -1.85006457, ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [-0.81787111, -0.95050604, -1.85006457, ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [ 1.21782949,  1.48757849,  1.49894114, ..., -0.49616526,
#          1.87905939, -0.22710335],
#        ...,
#        [ 0.3606924 , -0.24617051,  0.9686819 , ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [ 1.11068735,  0.07890743,  0.6895981 , ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [-0.71072897, -1.32976364,  0.41051429, ..., -0.49616526,
#          1.87905939, -0.22710335]])

# %%
X_test
# Out:
# array([[ 0.14640812, -0.95050604, -1.85006457, ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [ 1.32497163, -0.67960776,  0.95937911, ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [-0.28216042, -1.22140432, -1.85006457, ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        ...,
#        [-0.17501829, -1.11304501,  0.28957797, ..., -0.49616526,
#         -0.53218116, -0.22710335],
#        [-1.78215034, -0.1378112 ,  0.78262603, ...,  2.01545751,
#         -0.53218116, -0.22710335],
#        [-0.06787615,  1.48757849, -1.85006457, ..., -0.49616526,
#          1.87905939, -0.22710335]])

# %%
# %pip install tensorflow

# %%
# Part 2 - Now Let's make the ANN!
# Importing the Keras Librabies and Packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initializing the ANN
classifier = Sequential()

# Adding the Input layer and the First Hidden Layer
classifier.add(Dense(units=6,kernel_initializer='glorot_uniform',activation='relu',input_dim=X_train.shape[1]))

# Adding the Second Hidden Layer
classifier.add(Dense(units=6,kernel_initializer='glorot_uniform',activation='relu'))

# Adding the output layer
classifier.add(Dense(units = 1,kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history = classifier.fit(X_train,Y_train,validation_split=0.33,batch_size=10,epochs = 100)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6481 - accuracy: 0.5662 - val_loss: 0.6398 - val_accuracy: 0.5226
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5862 - accuracy: 0.6029 - val_loss: 0.5900 - val_accuracy: 0.5967
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.6802 - val_loss: 0.5428 - val_accuracy: 0.6708
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7454 - val_loss: 0.5014 - val_accuracy: 0.7572
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8065 - val_loss: 0.4631 - val_accuracy: 0.8107
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3861 - accuracy: 0.8432 - val_loss: 0.4356 - val_accuracy: 0.8313
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3564 - accuracy: 0.8513 - val_loss: 0.4171 - val_accuracy: 0.8354
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8595 - val_loss: 0.4068 - val_accuracy: 0.8477
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3217 - accuracy: 0.8676 - val_loss: 0.3975 - val_accuracy: 0.8519
# Epoch 10/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3112 - accuracy: 0.8635 - val_loss: 0.3960 - val_accuracy: 0.8519
# Epoch 11/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.8635 - val_loss: 0.3932 - val_accuracy: 0.8601
# Epoch 12/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2969 - accuracy: 0.8656 - val_loss: 0.3906 - val_accuracy: 0.8601
# Epoch 13/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2915 - accuracy: 0.8737 - val_loss: 0.3874 - val_accuracy: 0.8601
# Epoch 14/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.
100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1812 - accuracy: 0.9430 - val_loss: 0.4524 - val_accuracy: 0.8477
# Epoch 75/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 0.9430 - val_loss: 0.4526 - val_accuracy: 0.8436
# Epoch 76/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1803 - accuracy: 0.9409 - val_loss: 0.4523 - val_accuracy: 0.8477
# Epoch 77/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1788 - accuracy: 0.9470 - val_loss: 0.4550 - val_accuracy: 0.8477
# Epoch 78/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1781 - accuracy: 0.9430 - val_loss: 0.4560 - val_accuracy: 0.8477
# Epoch 79/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1776 - accuracy: 0.9430 - val_loss: 0.4590 - val_accuracy: 0.8436
# Epoch 80/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1768 - accuracy: 0.9430 - val_loss: 0.4579 - val_accuracy: 0.8477
# Epoch 81/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9328 - val_loss: 0.4597 - val_accuracy: 0.8477
# Epoch 82/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1774 - accuracy: 0.9409 - val_loss: 0.4563 - val_accuracy: 0.8477
# Epoch 83/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1754 - accuracy: 0.9430 - val_loss: 0.4567 - val_accuracy: 0.8519
# Epoch 84/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1745 - accuracy: 0.9430 - val_loss: 0.4601 - val_accuracy: 0.8519
# Epoch 85/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1747 - accuracy: 0.9430 - val_loss: 0.4619 - val_accuracy: 0.8560
# Epoch 86/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1740 - accuracy: 0.9430 - val_loss: 0.4595 - val_accuracy: 0.8560
# Epoch 87/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1761 - accuracy: 0.9430 - val_loss: 0.4593 - val_accuracy: 0.8519
# Epoch 88/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1734 - accuracy: 0.9491 - val_loss: 0.4619 - val_accuracy: 0.8560
# Epoch 89/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1718 - accuracy: 0.9430 - val_loss: 0.4619 - val_accuracy: 0.8560
# Epoch 90/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9491 - val_loss: 0.4601 - val_accuracy: 0.8519
# Epoch 91/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1715 - accuracy: 0.9491 - val_loss: 0.4619 - val_accuracy: 0.8477
# Epoch 92/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9491 - val_loss: 0.4647 - val_accuracy: 0.8560
# Epoch 93/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1701 - accuracy: 0.9430 - val_loss: 0.4650 - val_accuracy: 0.8560
# Epoch 94/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.9470 - val_loss: 0.4690 - val_accuracy: 0.8560
# Epoch 95/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1686 - accuracy: 0.9511 - val_loss: 0.4704 - val_accuracy: 0.8560
# Epoch 96/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.9532 - val_loss: 0.4690 - val_accuracy: 0.8519
# Epoch 97/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.9450 - val_loss: 0.4685 - val_accuracy: 0.8560
# Epoch 98/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1683 - accuracy: 0.9532 - val_loss: 0.4718 - val_accuracy: 0.8560
# Epoch 99/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1667 - accuracy: 0.9532 - val_loss: 0.4721 - val_accuracy: 0.8519
# Epoch 100/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9491 - val_loss: 0.4740 - val_accuracy: 0.8560

# %%
# Summarize History for Accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.legend(['train','test'],loc='lower right')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
# Part 3 : Making Predictions and Evaluating the Model

# Predicting the test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,Y_test)
score
# Out:
# 6/6 [==============================] - 0s 0s/step
# 0.8206521739130435

# %%
import pickle
file = open('this_is_it.pkl','wb')
pickle.dump(model_history, file)
